# %%
###  loops - for loop, while loop
list1 = [3,4,5,6,7,8]

list1[0]**2 
list1 = [3,4,5,6,7,8]
list2 = []
for element  in list1:
    if element%2 != 0 :
        list2.append(element**2)

print(list2)


list1 = [3,4,5,6,7,8]
for element  in list1:
    if element%2 == 0 :

        index = list1.index(element)
        list1[index] =  list1[index]**2
print(list1)


list1 = [3,4,5,6,7,8]
print(list1)
element  = 4
a = list1.index(element)
list1[a] = list1[a]**2
print(list1)


element  = 4

list1[list1.index(element)] = 1000

print(list1)
list1 = [3,4,5,6,7,8,9,3,8]
for element  in list1:
    index = list1.index(element)
    list1[index] =  list1[index]**2
print(list1)


print(list(range(len(list1))))
list1 = [3,4,5,6,7,8,9,3,8]
for index  in range(len(list1)):
    list1[index] =  list1[index]**2
print(list1)


list1 = [1,2,3,1]
list1.index(1)
